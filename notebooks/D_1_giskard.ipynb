# %%
from devtools import debug
from dotenv import load_dotenv

load_dotenv(verbose=True)

# %load_ext autoreload
# %autoreload 2

# !export PYTHONPATH=":./python"

# %%
#!pip3 install -U langchain-community faiss-cpu langchain-openai tiktoken
#!pip3 install -U giskard

# %%
from langchain.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
import giskard
import pandas as pd
from langchain_community.document_loaders import PyPDFLoader

# %%
# Prepare vector store (FAISS) with IPPC report

from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain.chains.retrieval import create_retrieval_chain

from python.ai_core.embeddings import EmbeddingsFactory
from python.ai_core.llm import get_llm
from python.ai_core.prompts import def_prompt
from python.ai_core.vector_store import VectorStoreFactory

vs_factory = VectorStoreFactory(
    id="Chroma_in_memory",
    collection_name="giskard_test",
    embeddings_factory=EmbeddingsFactory(),
)

DOC = (
    "https://www.ipcc.ch/report/ar6/syr/downloads/report/IPCC_AR6_SYR_LongerReport.pdf"
)
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000, chunk_overlap=100, add_start_index=True
)
documents = PyPDFLoader(DOC).load()
texts = text_splitter.split_documents(documents)
vs_factory.add_documents(texts)


# Prepare QA chain
system_prompt = """You are the Climate Assistant, a helpful AI assistant made by Giskard.
Your task is to answer common questions on climate change.
You will be given a question and relevant excerpts from the IPCC Climate Change Synthesis Report (2023).
Please provide short and clear answers based on the provided context. Be polite and helpful.

Context:
{context}"""

user_prompt = """
Question:
{question}

Your answer:
"""

llm = get_llm(llm_id="gpt_35_openai")


prompt = def_prompt(system=system_prompt, user=user_prompt)
question_answer_chain = create_stuff_documents_chain(llm, prompt)
climate_qa_chain = create_retrieval_chain(
    vs_factory.vector_store.as_retriever(), question_answer_chain
)

# chain.invoke({"input": query})
# Out:
# 2024-07-08 22:45:46,466 pid:8938 MainThread pypdf._reader WARNING  Ignoring wrong pointing object 110 0 (offset 0)
# 2024-07-08 22:45:46,468 pid:8938 MainThread pypdf._reader WARNING  Ignoring wrong pointing object 531 0 (offset 0)
# 2024-07-08 22:45:46,472 pid:8938 MainThread pypdf._reader WARNING  Ignoring wrong pointing object 968 0 (offset 0)
# 2024-07-08 22:45:46,473 pid:8938 MainThread pypdf._reader WARNING  Ignoring wrong pointing object 998 0 (offset 0)
# 2024-07-08 22:45:46,474 pid:8938 MainThread pypdf._reader WARNING  Ignoring wrong pointing object 1034 0 (offset 0)
# 2024-07-08 22:45:46,476 pid:8938 MainThread pypdf._reader WARNING  Ignoring wrong pointing object 1221 0 (offset 0)
# 2024-07-08 22:45:46,477 pid:8938 MainThread pypdf._reader WARNING  Ignoring wrong pointing object 1224 0 (offset 0)
# 2024-07-08 22:45:46,477 pid:8938 MainThread pypdf._reader WARNING  Ignoring wrong pointing object 1226 0 (offset 0)
# 2024-07-08 22:45:46,478 pid:8938 MainThread pypdf._reader WARNING  Ignoring wrong pointing object 1228 0 (offset 0)
# 2024-07-08 22:45:46,480 pid:8938 MainThread pypdf._reader WARNING  Ignoring wrong pointing object 1230 0 (offset 0)
# 2024-07-08 22:45:46,481 pid:8938 MainThread pypdf._reader WARNING  Ignoring wrong pointing object 1232 0 (offset 0)
# 2024-07-08 22:45:46,482 pid:8938 MainThread pypdf._reader WARNING  Ignoring wrong pointing object 1233 0 (offset 0)
# 2024-07-08 22:45:46,483 pid:8938 MainThread pypdf._reader WARNING  Ignoring wrong pointing object 1237 0 (offset 0)
# 2024-07-08 22:45:46,484 pid:8938 MainThread pypdf._reader WARNING  Ignoring wrong pointing object 1354 0 (offset 0)
# 2024-07-08 22:45:46,485 pid:8938 MainThread pypdf._reader WARNING  Ignoring wrong pointing object 1380 0 (offset 0)
# 2024-07-08 22:45:46,486 pid:8938 MainThread pypdf._reader WARNING  Ignoring wrong pointing object 1397 0 (offset 0)
# 2024-07-08 22:45:46,487 pid:8938 MainThread pypdf._reader WARNING  Ignoring wrong pointing object 1399 0 (offset 0)
# 2024-07-08 22:45:46,488 pid:8938 MainThread pypdf._reader WARNING  Ignoring wrong pointing object 1402 0 (offset 0)
# 2024-07-08 22:45:46,489 pid:8938 MainThread pypdf._reader WARNING  Ignoring wrong pointing object 1708 0 (offset 0)
# 2024-07-08 22:45:46,490 pid:8938 MainThread pypdf._reader WARNING  Ignoring wrong pointing object 1711 0 (offset 0)
# 2024-07-08 22:45:46,491 pid:8938 MainThread pypdf._reader WARNING  Ignoring wrong pointing object 1714 0 (offset 0)
# 2024-07-08 22:45:46,492 pid:8938 MainThread pypdf._reader WARNING  Ignoring wrong pointing object 1717 0 (offset 0)
# 2024-07-08 22:45:46,497 pid:8938 MainThread pypdf._reader WARNING  Ignoring wrong pointing object 1720 0 (offset 0)
# 2024-07-08 22:45:46,498 pid:8938 MainThread pypdf._reader WARNING  Ignoring wrong pointing object 1724 0 (offset 0)
# 2024-07-08 22:45:46,499 pid:8938 MainThread pypdf._reader WARNING  Ignoring wrong pointing object 1728 0 (offset 0)
# 2024-07-08 22:45:46,500 pid:8938 MainThread pypdf._reader WARNING  Ignoring wrong pointing object 1731 0 (offset 0)
# 2024-07-08 22:45:46,501 pid:8938 MainThread pypdf._reader WARNING  Ignoring wrong pointing object 1734 0 (offset 0)
# 2024-07-08 22:45:46,502 pid:8938 MainThread pypdf._reader WARNING  Ignoring wrong pointing object 1745 0 (offset 0)
# 2024-07-08 22:45:46,502 pid:8938 MainThread pypdf._reader WARNING  Ignoring wrong pointing object 1757 0 (offset 0)
# 2024-07-08 22:45:46,503 pid:8938 MainThread pypdf._reader WARNING  Ignoring wrong pointing object 1770 0 (offset 0)
# 2024-07-08 22:45:46,504 pid:8938 MainThread pypdf._reader WARNING  Ignoring wrong pointing object 1817 0 (offset 0)
# 2024-07-08 22:45:46,505 pid:8938 MainThread pypdf._reader WARNING  Ignoring wrong pointing object 1827 0 (offset 0)
# 2024-07-08 22:45:46,514 pid:8938 MainThread pypdf._reader WARNING  Ignoring wrong pointing object 1829 0 (offset 0)
# 2024-07-08 22:45:46,514 pid:8938 MainThread pypdf._reader WARNING  Ignoring wrong pointing object 1831 0 (offset 0)
# 2024-07-08 22:45:46,515 pid:8938 MainThread pypdf._reader WARNING  Ignoring wrong pointing object 1838 0 (offset 0)
# 2024-07-08 22:45:46,516 pid:8938 MainThread pypdf._reader WARNING  Ignoring wrong pointing object 1840 0 (offset 0)
# 2024-07-08 22:45:46,517 pid:8938 MainThread pypdf._reader WARNING  Ignoring wrong pointing object 1842 0 (offset 0)
# 2024-07-08 22:45:46,518 pid:8938 MainThread pypdf._reader WARNING  Ignoring wrong pointing object 1849 0 (offset 0)
# 2024-07-08 22:45:46,519 pid:8938 MainThread pypdf._reader WARNING  Ignoring wrong pointing object 1852 0 (offset 0)
# 2024-07-08 22:45:46,519 pid:8938 MainThread pypdf._reader WARNING  Ignoring wrong pointing object 1855 0 (offset 0)
# 2024-07-08 22:45:46,520 pid:8938 MainThread pypdf._reader WARNING  Ignoring wrong pointing object 1858 0 (offset 0)
# 2024-07-08 22:45:46,521 pid:8938 MainThread pypdf._reader WARNING  Ignoring wrong pointing object 1863 0 (offset 0)
# 2024-07-08 22:45:46,522 pid:8938 MainThread pypdf._reader WARNING  Ignoring wrong pointing object 1866 0 (offset 0)
# 2024-07-08 22:45:46,530 pid:8938 MainThread pypdf._reader WARNING  Ignoring wrong pointing object 1869 0 (offset 0)
# 2024-07-08 22:45:46,531 pid:8938 MainThread pypdf._reader WARNING  Ignoring wrong pointing object 1874 0 (offset 0)
# 2024-07-08 22:45:46,532 pid:8938 MainThread pypdf._reader WARNING  Ignoring wrong pointing object 1879 0 (offset 0)
# 2024-07-08 22:45:46,533 pid:8938 MainThread pypdf._reader WARNING  Ignoring wrong pointing object 1882 0 (offset 0)
# 2024-07-08 22:45:46,534 pid:8938 MainThread pypdf._reader WARNING  Ignoring wrong pointing object 1885 0 (offset 0)
# 2024-07-08 22:45:46,537 pid:8938 MainThread pypdf._reader WARNING  Ignoring wrong pointing object 2547 0 (offset 0)
# 2024-07-08 22:46:02.566 | INFO     | python.ai_core.vector_store:vector_store:113 - get vector store  : Chroma_in_memory/giskard_test_multilingual_MiniLM_local
# 2024-07-08 22:46:23.933 | INFO     | python.ai_core.llm:get_llm:405 - get LLM : gpt_35_openai - configurable: True
# 2024-07-08 22:46:26.208 | INFO     | python.ai_core.llm:get_configurable:361 - Cannot load gemini_pro_google: No module named 'langchain_google_vertexai'

# %%
def model_predict(df: pd.DataFrame):
    """Wraps the LLM call in a simple Python function.

    The function takes a pandas.DataFrame containing the input variables needed
    by your model, and must return a list of the outputs (one for each row).
    """
    return [climate_qa_chain.invoke({"query": question}) for question in df["question"]]

# %%
import giskard
import os
from giskard.llm.client.openai import OpenAIClient


giskard.llm.set_llm_api("openai")
oc = OpenAIClient(model="gpt-4-turbo-preview")
giskard.llm.set_default_client(oc)

giskard_model = giskard.Model(
    model=model_predict,
    model_type="text_generation",
    name="Climate Change Question Answering",
    description="This model answers any question about climate change based on IPCC reports",
    feature_names=["question"],
)
# Out:
# 2024-07-08 23:46:49,651 pid:8938 MainThread giskard.models.automodel INFO     Your 'prediction_function' is successfully wrapped by Giskard's 'PredictionFunctionModel' wrapper class.

# %%
scan_results = giskard.scan(giskard_model)
# Out:
# 2024-07-08 23:48:28,930 pid:8938 MainThread httpx        INFO     HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 🔎 Running scan…
# Estimated calls to your model: ~365
# Estimated LLM calls for evaluation: 148
#
# 2024-07-08 23:48:30,189 pid:8938 MainThread giskard.scanner.logger INFO     Running detectors: ['LLMBasicSycophancyDetector', 'LLMCharsInjectionDetector', 'LLMHarmfulContentDetector', 'LLMImplausibleOutputDetector', 'LLMInformationDisclosureDetector', 'LLMOutputFormattingDetector', 'LLMPromptInjectionDetector', 'LLMStereotypesDetector', 'LLMFaithfulnessDetector']
# Running detector LLMBasicSycophancyDetector…
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 scan_results = giskard.scan(giskard_model)
#
# File ~/.cache/pypoetry/virtualenvs/genai-blueprint-2X6HL8i2-py3.10/lib/python3.10/site-packages/giskard/scanner/__init__.py:64, in scan(model, dataset, features, params, only, verbose, raise_exceptions)
#      35 """Automatically detects model vulnerabilities.
#      36
#      37 See :class:`Scanner` for more details.
#    (...)
#      61     A scan report object containing the results of the scan.
#      62 """
#      63 scanner = Scanner(params, only=only)
# ---> 64 return scanner.analyze(
#      65     model, dataset=dataset, features=features, verbose=verbose, raise_exceptions=raise_exceptions
#      66 )
#
# File ~/.cache/pypoetry/virtualenvs/genai-blueprint-2X6HL8i2-py3.10/lib/python3.10/site-packages/giskard/scanner/scanner.py:124, in Scanner.analyze(self, model, dataset, features, verbose, raise_exceptions)
#     122 with warnings.catch_warnings():
#     123     warnings.simplefilter("ignore")
# --> 124     issues, errors = self._run_detectors(
#     125         detectors, model, dataset, features, verbose=verbose, raise_exceptions=raise_exceptions
#     126     )
#     128 issues = self._postprocess(issues)
#     130 # Scan completed
#
# File ~/.cache/pypoetry/virtualenvs/genai-blueprint-2X6HL8i2-py3.10/lib/python3.10/site-packages/giskard/scanner/scanner.py:152, in Scanner._run_detectors(self, detectors, model, dataset, features, verbose, raise_exceptions)
#     150 detector_start = perf_counter()
#     151 try:
# --> 152     detected_issues = detector.run(model, dataset, features=features)
#     153 except Exception as err:
#     154     logger.exception(f"Detector {detector.__class__.__name__} failed with error: {err}")
#
# File ~/.cache/pypoetry/virtualenvs/genai-blueprint-2X6HL8i2-py3.10/lib/python3.10/site-packages/giskard/scanner/llm/llm_basic_sycophancy_detector.py:85, in LLMBasicSycophancyDetector.run(self, model, dataset, features)
#      82 languages = dataset.extract_languages(columns=model.meta.feature_names)
#      84 generator = SycophancyDataGenerator(languages=languages)
# ---> 85 dataset1, dataset2 = generator.generate_dataset(
#      86     model, num_samples=self.num_samples, column_types=dataset.column_types
#      87 )
#      88 logger.debug(f"{self.__class__.__name__}: Generated {len(dataset1)} test inputs for model assessment.")
#      90 # Evaluate the answers
#
# File ~/.cache/pypoetry/virtualenvs/genai-blueprint-2X6HL8i2-py3.10/lib/python3.10/site-packages/giskard/llm/generators/sycophancy.py:101, in SycophancyDataGenerator.generate_dataset(self, model, num_samples, column_types)
#      98 def generate_dataset(self, model: BaseModel, num_samples=10, column_types=None):
#      99     messages = self._format_messages(model, num_samples)
# --> 101     out = self.llm_client.complete(
#     102         messages=messages,
#     103         temperature=self.llm_temperature,
#     104         caller_id=self.__class__.__name__,
#     105         seed=self.llm_seed,
#     106         format="json",
#     107     )
#     109     input_pairs = self._parse_output(out)
#     111     dataset_1 = Dataset(
#     112         pd.DataFrame([p["input_1"] for p in input_pairs]),
#     113         name=f"Sycophancy examples for {model.name} (set 1)",
#     114         column_types=column_types,
#     115         validation=False,
#     116     )
#
# File ~/.cache/pypoetry/virtualenvs/genai-blueprint-2X6HL8i2-py3.10/lib/python3.10/site-packages/giskard/llm/client/openai.py:63, in OpenAIClient.complete(self, messages, temperature, max_tokens, caller_id, seed, format)
#      60         extra_params["response_format"] = {"type": "json_object"}
#      62 try:
# ---> 63     completion = self._client.chat.completions.create(
#      64         model=self.model,
#      65         messages=[asdict(m) for m in messages],
#      66         temperature=temperature,
#      67         max_tokens=max_tokens,
#      68         **extra_params,
#      69     )
#      70 except openai.AuthenticationError as err:
#      71     raise LLMConfigurationError(AUTH_ERROR_MESSAGE) from err
#
# File ~/.cache/pypoetry/virtualenvs/genai-blueprint-2X6HL8i2-py3.10/lib/python3.10/site-packages/sentry_sdk/utils.py:1713, in ensure_integration_enabled.<locals>.patcher.<locals>.runner(*args, **kwargs)
#    1710 if sentry_sdk.get_client().get_integration(integration) is None:
#    1711     return original_function(*args, **kwargs)
# -> 1713 return sentry_patched_function(*args, **kwargs)
#
# File ~/.cache/pypoetry/virtualenvs/genai-blueprint-2X6HL8i2-py3.10/lib/python3.10/site-packages/sentry_sdk/integrations/openai.py:151, in _wrap_chat_completion_create.<locals>.new_chat_completion(*args, **kwargs)
#     149 span.__enter__()
#     150 try:
# --> 151     res = f(*args, **kwargs)
#     152 except Exception as e:
#     153     _capture_exception(e)
#
# File ~/.cache/pypoetry/virtualenvs/genai-blueprint-2X6HL8i2-py3.10/lib/python3.10/site-packages/openai/_utils/_utils.py:277, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     275             msg = f"Missing required argument: {quote(missing[0])}"
#     276     raise TypeError(msg)
# --> 277 return func(*args, **kwargs)
#
# File ~/.cache/pypoetry/virtualenvs/genai-blueprint-2X6HL8i2-py3.10/lib/python3.10/site-packages/openai/resources/chat/completions.py:643, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, parallel_tool_calls, presence_penalty, response_format, seed, service_tier, stop, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     609 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     610 def create(
#     611     self,
#    (...)
#     641     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     642 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
# --> 643     return self._post(
#     644         "/chat/completions",
#     645         body=maybe_transform(
#     646             {
#     647                 "messages": messages,
#     648                 "model": model,
#     649                 "frequency_penalty": frequency_penalty,
#     650                 "function_call": function_call,
#     651                 "functions": functions,
#     652                 "logit_bias": logit_bias,
#     653                 "logprobs": logprobs,
#     654                 "max_tokens": max_tokens,
#     655                 "n": n,
#     656                 "parallel_tool_calls": parallel_tool_calls,
#     657                 "presence_penalty": presence_penalty,
#     658                 "response_format": response_format,
#     659                 "seed": seed,
#     660                 "service_tier": service_tier,
#     661                 "stop": stop,
#     662                 "stream": stream,
#     663                 "stream_options": stream_options,
#     664                 "temperature": temperature,
#     665                 "tool_choice": tool_choice,
#     666                 "tools": tools,
#     667                 "top_logprobs": top_logprobs,
#     668                 "top_p": top_p,
#     669                 "user": user,
#     670             },
#     671             completion_create_params.CompletionCreateParams,
#     672         ),
#     673         options=make_request_options(
#     674             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     675         ),
#     676         cast_to=ChatCompletion,
#     677         stream=stream or False,
#     678         stream_cls=Stream[ChatCompletionChunk],
#     679     )
#
# File ~/.cache/pypoetry/virtualenvs/genai-blueprint-2X6HL8i2-py3.10/lib/python3.10/site-packages/openai/_base_client.py:1250, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1236 def post(
#    1237     self,
#    1238     path: str,
#    (...)
#    1245     stream_cls: type[_StreamT] | None = None,
#    1246 ) -> ResponseT | _StreamT:
#    1247     opts = FinalRequestOptions.construct(
#    1248         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1249     )
# -> 1250     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/.cache/pypoetry/virtualenvs/genai-blueprint-2X6HL8i2-py3.10/lib/python3.10/site-packages/openai/_base_client.py:931, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     922 def request(
#     923     self,
#     924     cast_to: Type[ResponseT],
#    (...)
#     929     stream_cls: type[_StreamT] | None = None,
#     930 ) -> ResponseT | _StreamT:
# --> 931     return self._request(
#     932         cast_to=cast_to,
#     933         options=options,
#     934         stream=stream,
#     935         stream_cls=stream_cls,
#     936         remaining_retries=remaining_retries,
#     937     )
#
# File ~/.cache/pypoetry/virtualenvs/genai-blueprint-2X6HL8i2-py3.10/lib/python3.10/site-packages/openai/_base_client.py:962, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     959 log.debug("Sending HTTP Request: %s %s", request.method, request.url)
#     961 try:
# --> 962     response = self._client.send(
#     963         request,
#     964         stream=stream or self._should_stream_response_body(request=request),
#     965         **kwargs,
#     966     )
#     967 except httpx.TimeoutException as err:
#     968     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File ~/.cache/pypoetry/virtualenvs/genai-blueprint-2X6HL8i2-py3.10/lib/python3.10/site-packages/sentry_sdk/utils.py:1713, in ensure_integration_enabled.<locals>.patcher.<locals>.runner(*args, **kwargs)
#    1710 if sentry_sdk.get_client().get_integration(integration) is None:
#    1711     return original_function(*args, **kwargs)
# -> 1713 return sentry_patched_function(*args, **kwargs)
#
# File ~/.cache/pypoetry/virtualenvs/genai-blueprint-2X6HL8i2-py3.10/lib/python3.10/site-packages/sentry_sdk/integrations/httpx.py:88, in _install_httpx_client.<locals>.send(self, request, **kwargs)
#      85         else:
#      86             request.headers[key] = value
# ---> 88 rv = real_send(self, request, **kwargs)
#      90 span.set_http_status(rv.status_code)
#      91 span.set_data("reason", rv.reason_phrase)
#
# File ~/.cache/pypoetry/virtualenvs/genai-blueprint-2X6HL8i2-py3.10/lib/python3.10/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     906 follow_redirects = (
#     907     self.follow_redirects
#     908     if isinstance(follow_redirects, UseClientDefault)
#     909     else follow_redirects
#     910 )
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~/.cache/pypoetry/virtualenvs/genai-blueprint-2X6HL8i2-py3.10/lib/python3.10/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~/.cache/pypoetry/virtualenvs/genai-blueprint-2X6HL8i2-py3.10/lib/python3.10/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~/.cache/pypoetry/virtualenvs/genai-blueprint-2X6HL8i2-py3.10/lib/python3.10/site-packages/httpx/_client.py:1015, in Client._send_single_request(self, request)
#    1010     raise RuntimeError(
#    1011         "Attempted to send an async request with a sync Client instance."
#    1012     )
#    1014 with request_context(request=request):
# -> 1015     response = transport.handle_request(request)
#    1017 assert isinstance(response.stream, SyncByteStream)
#    1019 response.request = request
#
# File ~/.cache/pypoetry/virtualenvs/genai-blueprint-2X6HL8i2-py3.10/lib/python3.10/site-packages/httpx/_transports/default.py:233, in HTTPTransport.handle_request(self, request)
#     220 req = httpcore.Request(
#     221     method=request.method,
#     222     url=httpcore.URL(
#    (...)
#     230     extensions=request.extensions,
#     231 )
#     232 with map_httpcore_exceptions():
# --> 233     resp = self._pool.handle_request(req)
#     235 assert isinstance(resp.stream, typing.Iterable)
#     237 return Response(
#     238     status_code=resp.status,
#     239     headers=resp.headers,
#     240     stream=ResponseStream(resp.stream),
#     241     extensions=resp.extensions,
#     242 )
#
# File ~/.cache/pypoetry/virtualenvs/genai-blueprint-2X6HL8i2-py3.10/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:216, in ConnectionPool.handle_request(self, request)
#     213         closing = self._assign_requests_to_connections()
#     215     self._close_connections(closing)
# --> 216     raise exc from None
#     218 # Return the response. Note that in this case we still have to manage
#     219 # the point at which the response is closed.
#     220 assert isinstance(response.stream, Iterable)
#
# File ~/.cache/pypoetry/virtualenvs/genai-blueprint-2X6HL8i2-py3.10/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:196, in ConnectionPool.handle_request(self, request)
#     192 connection = pool_request.wait_for_connection(timeout=timeout)
#     194 try:
#     195     # Send the request on the assigned connection.
# --> 196     response = connection.handle_request(
#     197         pool_request.request
#     198     )
#     199 except ConnectionNotAvailable:
#     200     # In some cases a connection may initially be available to
#     201     # handle a request, but then become unavailable.
#     202     #
#     203     # In this case we clear the connection and try again.
#     204     pool_request.clear_connection()
#
# File ~/.cache/pypoetry/virtualenvs/genai-blueprint-2X6HL8i2-py3.10/lib/python3.10/site-packages/httpcore/_sync/connection.py:101, in HTTPConnection.handle_request(self, request)
#      98     self._connect_failed = True
#      99     raise exc
# --> 101 return self._connection.handle_request(request)
#
# File ~/.cache/pypoetry/virtualenvs/genai-blueprint-2X6HL8i2-py3.10/lib/python3.10/site-packages/httpcore/_sync/http11.py:143, in HTTP11Connection.handle_request(self, request)
#     141     with Trace("response_closed", logger, request) as trace:
#     142         self._response_closed()
# --> 143 raise exc
#
# File ~/.cache/pypoetry/virtualenvs/genai-blueprint-2X6HL8i2-py3.10/lib/python3.10/site-packages/httpcore/_sync/http11.py:113, in HTTP11Connection.handle_request(self, request)
#     102     pass
#     104 with Trace(
#     105     "receive_response_headers", logger, request, kwargs
#     106 ) as trace:
#     107     (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112         trailing_data,
# --> 113     ) = self._receive_response_headers(**kwargs)
#     114     trace.return_value = (
#     115         http_version,
#     116         status,
#     117         reason_phrase,
#     118         headers,
#     119     )
#     121 network_stream = self._network_stream
#
# File ~/.cache/pypoetry/virtualenvs/genai-blueprint-2X6HL8i2-py3.10/lib/python3.10/site-packages/httpcore/_sync/http11.py:186, in HTTP11Connection._receive_response_headers(self, request)
#     183 timeout = timeouts.get("read", None)
#     185 while True:
# --> 186     event = self._receive_event(timeout=timeout)
#     187     if isinstance(event, h11.Response):
#     188         break
#
# File ~/.cache/pypoetry/virtualenvs/genai-blueprint-2X6HL8i2-py3.10/lib/python3.10/site-packages/httpcore/_sync/http11.py:224, in HTTP11Connection._receive_event(self, timeout)
#     221     event = self._h11_state.next_event()
#     223 if event is h11.NEED_DATA:
# --> 224     data = self._network_stream.read(
#     225         self.READ_NUM_BYTES, timeout=timeout
#     226     )
#     228     # If we feed this case through h11 we'll raise an exception like:
#     229     #
#     230     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     234     # perspective. Instead we handle this case distinctly and treat
#     235     # it as a ConnectError.
#     236     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/.cache/pypoetry/virtualenvs/genai-blueprint-2X6HL8i2-py3.10/lib/python3.10/site-packages/httpcore/_backends/sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     124 with map_exceptions(exc_map):
#     125     self._sock.settimeout(timeout)
# --> 126     return self._sock.recv(max_bytes)
#
# File /usr/lib/python3.10/ssl.py:1288, in SSLSocket.recv(self, buflen, flags)
#    1284     if flags != 0:
#    1285         raise ValueError(
#    1286             "non-zero flags not allowed in calls to recv() on %s" %
#    1287             self.__class__)
# -> 1288     return self.read(buflen)
#    1289 else:
#    1290     return super().recv(buflen, flags)
#
# File /usr/lib/python3.10/ssl.py:1161, in SSLSocket.read(self, len, buffer)
#    1159         return self._sslobj.read(len, buffer)
#    1160     else:
# -> 1161         return self._sslobj.read(len)
#    1162 except SSLError as x:
#    1163     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %%
display(scan_results)

# %%
# Or save it to a file
scan_results.to_html("scan_results.html")
